# %%
import pandas as pd

# %%
import pandas_datareader.data as web
import datetime

# %%
start = datetime.datetime(2017,1,1)
end = datetime.datetime(2018,4,5)
f = web.DataReader('AAPL', 'yahoo', start,end)

# %%
f.loc['2018-02-06'] # Data of a sample date
# Out:
# Open         1.548300e+02
# High         1.637200e+02
# Low          1.540000e+02
# Close        1.630300e+02
# Adj Close    1.611790e+02
# Volume       6.824380e+07
# Name: 2018-02-06 00:00:00, dtype: float64

# %%
start = datetime.datetime(2015,1,2)
end = datetime.datetime(2016,1,27)
f = web.DataReader('0005.HK', 'yahoo', start,end)

# %%
f
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  73.599998  74.099998  73.500000  74.000000  58.735512   8614012
# 2015-01-05  73.150002  73.349998  72.800003  72.900002  57.862404  21629040
# 2015-01-06  71.800003  71.849998  71.349998  71.750000  56.949635  35110417
# 2015-01-07  70.500000  71.099998  70.449997  71.000000  56.354340  35378291
# 2015-01-08  71.050003  71.400002  71.000000  71.199997  56.513088  21320949
# 2015-01-09  71.300003  71.449997  71.000000  71.099998  56.433712  22291858
# 2015-01-12  71.000000  71.199997  70.650002  71.099998  56.433712  13748156
# 2015-01-13  71.099998  71.500000  70.800003  71.300003  56.592461  14096443
# 2015-01-14  71.099998  71.099998  70.699997  70.849998  56.235275  17300306
# 2015-01-15  70.300003  70.699997  70.199997  70.599998  56.036846  22843530
# 2015-01-16  70.199997  70.400002  69.800003  70.199997  55.719364  27842543
# ...

# %%
f.loc['2016-01-04'] # Data of a sample date
# Out:
# Open         6.160000e+01
# High         6.160000e+01
# Low          6.015000e+01
# Close        6.040000e+01
# Adj Close    5.074143e+01
# Volume       2.050426e+07
# Name: 2016-01-04 00:00:00, dtype: float64
